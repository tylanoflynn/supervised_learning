# %% [markdown]
# - The os module has a perfect method to list files in a directory.
# - Pandas json normalize could work here but is not necessary to convert the JSON data to a dataframe.
# - You may need a nested for-loop to access each sale!
# - We've put a lot of time into creating the structure of this repository, and it's a good example for future projects.  In the file functions_variables.py, there is an example function that you can import and use.  If you have any variables, functions or classes that you want to make, they can be put in the functions_variables.py file and imported into a notebook.  Note that only .py files can be imported into a notebook. If you want to import everything from a .py file, you can use the following:
# ```python
# from functions_variables import *
# ```
# If you just import functions_variables, then each object from the file will need to be prepended with "functions_variables"\
# Using this .py file will keep your notebooks very organized and make it easier to reuse code between notebooks.

# %%
# (this is not an exhaustive list of libraries)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
import os
import json
from pprint import pprint

from modules.JSONFramer import JSONFramer

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
JSONFramer = JSONFramer('../data')
df = JSONFramer.frame()
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8159 entries, 0 to 8158
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   branding_name          7910 non-null   object
#  1   baths                  7980 non-null   float64
#  2   baths_1qtr             0 non-null      object
#  3   baths_3qr              0 non-null      object
#  4   baths_full             7311 non-null   object
#  5   baths_half             2281 non-null   object
#  6   beds                   7504 non-null   object
#  7   garage                 4448 non-null   object
#  8   lot_sqft               6991 non-null   object
#  9   name                   0 non-null      object
#  10  sold_date              8159 non-null   object
#  11  sold_price             6716 non-null   object
#  12  sqft                   7323 non-null   object
#  13  stories                6260 non-null   object
#  14  sub_type               1427 non-null   object
#  15  type                   8125 non-null   object
#  16  year_built             7316 non-null   object
#  17  is_coming_soon         0 non-null      object
#  18  is_contingent          0 non-null      object
#  19  is_for_rent            0 non-null      object
#  20  is_foreclosure         42 non-null     object
#  21  is_new_construction    0 non-null      object
#  22  is_new_listing         7752 non-null   object
#  23  is_pending             0 non-null      object
#  24  is_plan                0 non-null      object
#  25  is_price_reduced       2484 non-null   object
#  26  is_subdivision         0 non-null      object
#  27  last_update_date       8125 non-null   object
#  28  show_contact_an_agent  8159 non-null   bool
#  29  list_date              7752 non-null   object
#  30  list_price             7721 non-null   object
#  31  listing_id             7752 non-null   object
#  32  city                   8154 non-null   object
#  33  lat                    7909 non-null   object
#  34  lon                    7909 non-null   object
#  35  line                   8144 non-null   object
#  36  postal_code            8159 non-null   object
#  37  state                  8159 non-null   object
#  38  state_code             8159 non-null   object
#  39  open_houses            0 non-null      object
#  40  price_reduced_amount   2484 non-null   object
#  41  brand_name             7673 non-null   object
#  42  property_id            8159 non-null   object
#  43  status                 8159 non-null   object
#  44  tags                   7638 non-null   object
# dtypes: bool(1), float64(1), object(43)
# memory usage: 2.7+ MB

# %%
#count unique property ids
df['property_id'].nunique()
#1795 unique property_ids in a dataframe of 8159 rows indicates that row duplication exists for each property
# Out:
# 1795

# %%
#display df sorted by 'property_id' column to visually inspect the data
df.sort_values(by=['property_id']).head(6)
#Quick check shows that multiple values for 'branding_name' column exist for each property_id
# Out:
#                                  branding_name  baths baths_1qtr baths_3qr  \
# 6194                                   Compass    3.0       None      None
# 1837  Weichert, Realtors - Courtney Valleywide    3.0       None      None
# 7199                 My Home Group Real Estate    3.0       None      None
# 571              Cooper Premier Properties Llc    3.0       None      None
# 6386     Keller Williams Realty Sonoran Living    3.0       None      None
# 3479             Sell Your Home Services, Inc.    3.0       None      None
#
#      baths_full baths_half beds garage lot_sqft  name   sold_date sold_price  \
# 6194        3.0        NaN  3.0    5.0    43560  None  2023-12-15     925000
# 1837        3.0       None  4.0    2.0  95832.0  None  2023-12-22     625600
# 7199        3.0       None  4.0    2.0  95832.0  None  2023-12-22     625600
# 571         3.0       None  4.0    2.0  95832.0  None  2023-12-22     625600
# 6386        3.0       None  4.0    2.0  95832.0  None  2023-12-22     625600
# 3479        3.0       None  4.0    2.0  95832.0  None  2023-12-22     625600
#
#         sqft stories sub_type           type year_built is_coming_soon  \
# 6194  2980.0     1.0     None  single_family     1978.0           None
# 1837  2136.0     1.0     None  single_family     1996.0           None
# 7199  2136.0     1.0     None  single_family     1996.0           None
# 571   2136.0     1.0     None  single_family     1996.0           None
# 6386  2136.0     1.0     None  single_family     1996.0           None
# 3479  2136.0     1.0     None  single_family     1996.0           None
#
#      is_contingent is_for_rent is_foreclosure is_new_construction  \
# 6194          None        None           None                None
# 1837          None        None           None                None
# 7199          None        None           None                None
# 571           None        None           None                None
# 6386          None        None           None                None
# 3479          None        None           None                None
#
#      is_new_listing is_pending is_plan is_price_reduced is_subdivision  \
# 6194          False       None    None             None           None
# 1837          False       None    None             None           None
# 7199          False       None    None             None           None
# 571           False       None    None             None           None
# 6386          False       None    None             None           None
# 3479          False       None    None             None           None
#
#           last_update_date  show_contact_an_agent  \
# 6194  2023-12-15T21:25:24Z                   True
# 1837  2023-12-23T09:05:36Z                   True
# 7199  2023-12-23T09:05:36Z                   True
# 571   2023-12-23T09:05:36Z                   True
# 6386  2023-12-23T09:05:36Z                   True
# 3479  2023-12-23T09:05:36Z                   True
#
#                         list_date list_price  listing_id         city  \
# 6194  2023-09-25T16:20:27.000000Z     925000  2959966417  Carson City
# 1837  2023-11-20T16:22:33.000000Z     600000  2961854149      Phoenix
# 7199  2023-11-20T16:22:33.000000Z     600000  2961854149      Phoenix
# 571   2023-11-20T16:22:33.000000Z     600000  2961854149      Phoenix
# 6386  2023-11-20T16:22:33.000000Z     600000  2961854149      Phoenix
# 3479  2023-11-20T16:22:33.000000Z     600000  2961854149      Phoenix
#
#             lat         lon             line postal_code    state state_code  \
# 6194  39.093819  -119.79112  3527 Arcadia Dr       89705   Nevada         NV
# 1837  33.804177 -112.056055  35033 N 12th St       85086  Arizona         AZ
# 7199  33.804177 -112.056055  35033 N 12th St       85086  Arizona         AZ
# 571   33.804177 -112.056055  35033 N 12th St       85086  Arizona         AZ
# 6386  33.804177 -112.056055  35033 N 12th St       85086  Arizona         AZ
# 3479  33.804177 -112.056055  35033 N 12th St       85086  Arizona         AZ
#
#      open_houses price_reduced_amount    brand_name property_id status  \
# 6194        None                  NaN  basic_opt_in  1003442504   sold
# 1837        None                  NaN  basic_opt_in  1007849822   sold
# 7199        None                  NaN  basic_opt_in  1007849822   sold
# 571         None                  NaN  basic_opt_in  1007849822   sold
# 6386        None                  NaN  basic_opt_in  1007849822   sold
# 3479        None                  NaN  basic_opt_in  1007849822   sold
#
#                                                    tags
# 6194  [community_outdoor_space, energy_efficient, fa...
# 1837  [single_story, garage_1_or_more, garage_2_or_m...
# 7199  [single_story, garage_1_or_more, garage_2_or_m...
# 571   [single_story, garage_1_or_more, garage_2_or_m...
# 6386  [single_story, garage_1_or_more, garage_2_or_m...
# 3479  [single_story, garage_1_or_more, garage_2_or_m...

# %%
#check shape of the df after dropping duplicated 'branding_name' column and unhashable 'tags' column
temp_dataframe = df.drop(columns =['branding_name','tags'])
temp_dataframe.drop_duplicates().shape
#1795 rows is same number as unique property ids, therefore eliminating the branding_name column will remove duplicates
# Out:
# (1795, 43)

# %%
# #Note: the 'tags' column was checked for duplication by converting the list type of each value to a string and then applying '.drop_duplicates'

# def tas_to_string...

# string_data = all_data
# string_data.loc[:, 'tags'] = string_data['tags'].apply(lambda x: tags_to_string(x))

# string_data.drop_duplicates().info()

# # No duplication was found

# %%
#check to see how many unique 'branding_name' values there are (just in case there were only a few and we could keep this column)
len(df['branding_name'].unique())
#As expected, there are too many (172) so the column can be dropped
# Out:
# 172

# %% [markdown]
# **-Drop Columns:**

# %%
#drop the 'branding_name' column 
#also drop all columns with 0 non-null values including the following:
df = df.drop(columns = ['branding_name', 'baths_1qtr', 'baths_3qr', 'name', 'is_coming_soon', 'is_contingent', 'is_for_rent', 'is_new_construction', 'is_pending', 'is_plan', 'is_subdivision', 'open_houses'])

# df = dataframe.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8159 entries, 0 to 8158
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   baths                  7980 non-null   float64
#  1   baths_full             7311 non-null   object
#  2   baths_half             2281 non-null   object
#  3   beds                   7504 non-null   object
#  4   garage                 4448 non-null   object
#  5   lot_sqft               6991 non-null   object
#  6   sold_date              8159 non-null   object
#  7   sold_price             6716 non-null   object
#  8   sqft                   7323 non-null   object
#  9   stories                6260 non-null   object
#  10  sub_type               1427 non-null   object
#  11  type                   8125 non-null   object
#  12  year_built             7316 non-null   object
#  13  is_foreclosure         42 non-null     object
#  14  is_new_listing         7752 non-null   object
#  15  is_price_reduced       2484 non-null   object
#  16  last_update_date       8125 non-null   object
#  17  show_contact_an_agent  8159 non-null   bool
#  18  list_date              7752 non-null   object
#  19  list_price             7721 non-null   object
#  20  listing_id             7752 non-null   object
#  21  city                   8154 non-null   object
#  22  lat                    7909 non-null   object
#  23  lon                    7909 non-null   object
#  24  line                   8144 non-null   object
#  25  postal_code            8159 non-null   object
#  26  state                  8159 non-null   object
#  27  state_code             8159 non-null   object
#  28  price_reduced_amount   2484 non-null   object
#  29  brand_name             7673 non-null   object
#  30  property_id            8159 non-null   object
#  31  status                 8159 non-null   object
#  32  tags                   7638 non-null   object
# dtypes: bool(1), float64(1), object(31)
# memory usage: 2.0+ MB

# %% [markdown]
# **-Drop rows where target column is null:**

# %%
#Because our model's target variable is 'sold_price', we can drop all rows where this is null
df.dropna(subset=['sold_price'], inplace=True)
df.shape
# Out:
# (6716, 33)

# %% [markdown]
# **-Encode 'tags' in columns:**

# %%
#we need to explode and one-hot-code the 'tags' column
#(this needs to be done before dropping duplicated as the list data type for tags values is unhashable)

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
s = df['tags'].apply(lambda x: x if x is not None else [])
binarized_tags = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df.index)

binarized_tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6716 entries, 0 to 8158
# Columns: 152 entries, baseball to wrap_around_porch
# dtypes: int64(152)
# memory usage: 7.8 MB

# %%
df = df.merge(binarized_tags, left_index=True, right_index=True).drop(columns='tags')
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['baths', 'baths_full', 'baths_half', 'beds', 'garage', 'lot_sqft',
#        'sold_date', 'sold_price', 'sqft', 'stories',
#        ...
#        'views', 'volleyball', 'washer_dryer', 'water_view', 'waterfront',
#        'well_water', 'white_kitchen', 'wine_cellar', 'wooded_land',
#        'wrap_around_porch'],
#       dtype='object', length=184)

# %%
#Drop 'tags' column
#Perform count for all newly created binary tag columns / by total row count
#Drop all binary tag columns that are represented in less that [10%?] of the data



binarized_tags_dict = (df.loc[:, mlb.classes_.tolist()].sum()/df.shape[0]).to_dict()

binarized_tags_list = []

for key in binarized_tags_dict.keys():
    if binarized_tags_dict[key] < 0.05:
        binarized_tags_list.append(key)

binarized_tags_list
# Out:
# ['baseball',
#  'basketball',
#  'basketball_court',
#  'beach',
#  'beautiful_backyard',
#  'big_bathroom',
#  'boat_dock',
#  'cathedral_ceiling',
#  'clubhouse',
#  'coffer_ceiling',
#  'community_boat_facilities',
#  'community_center',
#  'community_clubhouse',
#  'community_elevator',
#  'community_golf',
#  'community_gym',
#  'community_horse_facilities',
#  'community_park',
#  'community_spa_or_hot_tub',
#  'community_tennis_court',
#  'courtyard_entry',
#  'cul_de_sac',
#  'den_or_office',
#  'detached_guest_house',
#  'dual_master_bedroom',
#  'efficient',
#  'elevator',
#  'exposed_brick',
#  'fenced_courtyard',
#  'first_floor_master_bedroom',
#  'fixer_upper',
#  'fruit_trees',
#  'furniture',
#  'game_room',
#  'gated_community',
#  'golf_course',
#  'golf_course_lot_or_frontage',
#  'golf_course_view',
#  'gourmet_kitchen',
#  'granite_kitchen',
#  'greenbelt',
#  'greenhouse',
#  'guest_house',
#  'guest_parking',
#  'handicap_access',
#  'hill_or_mountain_view',
#  'hoa',
#  'horse_facilities',
#  'indoor_basketball_court',
#  'investment_opportunity',
#  'jack_and_jill_bathroom',
#  'kitchen_island',
#  'lake',
#  'lake_view',
#  'large_kitchen',
#  'large_porch',
#  'library',
#  'low_hoa',
#  'maintenance',
#  'marina',
#  'master_bathroom',
#  'master_suite',
#  'media_room',
#  'medicalcare',
#  'mountain_view',
#  'no_hoa',
#  'ocean_view',
#  'open_house',
#  'open_kitchen',
#  'outbuilding',
#  'outdoor_kitchen',
#  'pets_allowed',
#  'playground',
#  'pond',
#  'private_backyard',
#  'private_bathroom',
#  'private_courtyard',
#  'private_parking',
#  'river_access',
#  'river_view',
#  'rv_or_boat_parking',
#  'rv_parking',
#  'screen_porch',
#  'security',
#  'senior_community',
#  'smart_homes',
#  'soccer',
#  'solar_panels',
#  'solar_system',
#  'spa_or_hot_tub',
#  'storm_shelter',
#  'tennis',
#  'tennis_court',
#  'theater_room',
#  'two_kitchen',
#  'two_master_suites',
#  'vaulted_ceiling',
#  'volleyball',
#  'water_view',
#  'waterfront',
#  'well_water',
#  'white_kitchen',
#  'wine_cellar',
#  'wooded_land',
#  'wrap_around_porch']

# %%
df = df.drop(columns=binarized_tags_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1475 entries, 0 to 8117
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   baths                        1443 non-null   float64
#  1   baths_full                   1329 non-null   object
#  2   baths_half                   434 non-null    object
#  3   beds                         1367 non-null   object
#  4   garage                       764 non-null    object
#  5   lot_sqft                     1275 non-null   object
#  6   sold_date                    1475 non-null   object
#  7   sold_price                   1475 non-null   object
#  8   sqft                         1331 non-null   object
#  9   stories                      1118 non-null   object
#  10  sub_type                     259 non-null    object
#  11  type                         1471 non-null   object
#  12  year_built                   1329 non-null   object
#  13  is_foreclosure               6 non-null      object
#  14  is_new_listing               1412 non-null   object
#  15  is_price_reduced             444 non-null    object
#  16  last_update_date             1471 non-null   object
#  17  show_contact_an_agent        1475 non-null   bool
#  18  list_date                    1412 non-null   object
#  19  list_price                   1412 non-null   object
#  20  listing_id                   1412 non-null   object
#  21  city                         1474 non-null   object
#  22  lat                          1435 non-null   object
#  23  lon                          1435 non-null   object
#  24  line                         1474 non-null   object
#  25  postal_code                  1475 non-null   object
#  26  state                        1475 non-null   object
#  27  state_code                   1475 non-null   object
#  28  price_reduced_amount         444 non-null    object
#  29  brand_name                   1397 non-null   object
#  30  property_id                  1475 non-null   object
#  31  status                       1475 non-null   object
#  32  basement                     1475 non-null   int64
#  33  big_lot                      1475 non-null   int64
#  34  big_yard                     1475 non-null   int64
#  35  carport                      1475 non-null   int64
#  36  central_air                  1475 non-null   int64
#  37  central_heat                 1475 non-null   int64
#  38  city_view                    1475 non-null   int64
#  39  community_outdoor_space      1475 non-null   int64
#  40  community_security_features  1475 non-null   int64
#  41  community_swimming_pool      1475 non-null   int64
#  42  corner_lot                   1475 non-null   int64
#  43  dining_room                  1475 non-null   int64
#  44  disability_features          1475 non-null   int64
#  45  dishwasher                   1475 non-null   int64
#  46  energy_efficient             1475 non-null   int64
#  47  ensuite                      1475 non-null   int64
#  48  family_room                  1475 non-null   int64
#  49  farm                         1475 non-null   int64
#  50  fenced_yard                  1475 non-null   int64
#  51  fireplace                    1475 non-null   int64
#  52  floor_plan                   1475 non-null   int64
#  53  forced_air                   1475 non-null   int64
#  54  front_porch                  1475 non-null   int64
#  55  garage_1_or_more             1475 non-null   int64
#  56  garage_2_or_more             1475 non-null   int64
#  57  garage_3_or_more             1475 non-null   int64
#  58  groundscare                  1475 non-null   int64
#  59  hardwood_floors              1475 non-null   int64
#  60  high_ceiling                 1475 non-null   int64
#  61  laundry_room                 1475 non-null   int64
#  62  master_bedroom               1475 non-null   int64
#  63  modern_kitchen               1475 non-null   int64
#  64  new_roof                     1475 non-null   int64
#  65  open_floor_plan              1475 non-null   int64
#  66  park                         1475 non-null   int64
#  67  ranch                        1475 non-null   int64
#  68  recreation_facilities        1475 non-null   int64
#  69  rental_property              1475 non-null   int64
#  70  shopping                     1475 non-null   int64
#  71  single_story                 1475 non-null   int64
#  72  swimming_pool                1475 non-null   int64
#  73  trails                       1475 non-null   int64
#  74  two_or_more_stories          1475 non-null   int64
#  75  updated_kitchen              1475 non-null   int64
#  76  view                         1475 non-null   int64
#  77  views                        1475 non-null   int64
#  78  washer_dryer                 1475 non-null   int64
# dtypes: bool(1), float64(1), int64(47), object(30)
# memory usage: 911.8+ KB

# %% [markdown]
# **-Fill N/A Values**

# %%
#fill N/A values with zeros for 'baths_half', 'garage', price_reduced_amount
df.update(df[['baths_full','baths_half', 'garage', 'price_reduced_amount']].fillna(0))

# %%
#fill N/A values with 'False' for 'is_price_reduced'
df['is_price_reduced'].fillna(False, inplace=True)

# %% [markdown]
# **-Drop more unecessary Columns**

# %%
#drop 'sub-type' column as it appears to be either missing or very similar to type in most instances
df.drop(columns='sub_type', inplace=True)

# %%
#We can probably drop 'last_update' column as I assume it has to do with website or realtor activity
df.drop(columns='last_update_date', inplace=True)

# %%
#Only False values for this column so we can drop it
#It might be the case that None type should be 'True' but I don't think we have enough info to make this inference
df.drop(columns='is_new_listing', inplace=True)

# %%
#Not obvious what brand name is - I suggest we drop but we could also just try modelling with it left in
df.drop(columns='brand_name', inplace=True)

# %%
#status is always sold so we can drop this
df.drop(columns='status', inplace=True)

# %% [markdown]
# **-Change Boolean values to Binary**

# %%
df.drop(columns='show_contact_an_agent', inplace=True)

# %%
#Do we want to drop the foreclosure column because so few data points exist?
df.drop(columns='is_foreclosure', inplace=True)
#Alternatively we can just fill thse values null values with False

# %%
df[df['beds'].isna()]
# Out:
#       baths baths_full baths_half beds garage   lot_sqft   sold_date  \
# 41      0.0        NaN        0.0  NaN    0.0    19800.0  2024-01-05
# 139     0.0        NaN        0.0  NaN    0.0   273992.0  2024-01-12
# 144     0.0        NaN        0.0  NaN    0.0    43560.0  2024-01-12
# 246     0.0        NaN        0.0  NaN    0.0    43560.0  2023-12-28
# 255     0.0        NaN        0.0  NaN    0.0   653400.0  2023-11-14
# 256     0.0        NaN        0.0  NaN    0.0   196020.0  2023-11-14
# 258     0.0        NaN        0.0  NaN    0.0  1348618.0  2023-10-24
# 265     0.0        NaN        0.0  NaN    0.0    24394.0  2023-08-22
# 267     0.0        NaN        0.0  NaN    0.0    51401.0  2023-08-22
# 268     0.0        NaN        0.0  NaN    0.0     6098.0  2023-08-22
# 269     0.0        NaN        0.0  NaN    0.0    11761.0  2023-08-22
# 270     0.0        NaN        0.0  NaN    0.0    73181.0  2023-08-22
# 271     0.0        NaN        0.0  NaN    0.0    18295.0  2023-08-22
# 274     0.0        NaN        0.0  NaN    0.0     8276.0  2023-08-08
# 334     0.0        NaN        0.0  NaN    0.0    3397680  2024-01-12
# 378     NaN        NaN        0.0  NaN    0.0     7405.0  2024-01-05
# 392     NaN        NaN        0.0  NaN    0.0    20038.0  2023-12-22
# 403     NaN        NaN        0.0  NaN    0.0     5227.0  2023-12-19
# 410     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-27
# 422     0.0        NaN        0.0  NaN    0.0     6316.0  2023-09-27
# 425     0.0        NaN        0.0  NaN    0.0     6098.0  2023-08-18
# 426     0.0        NaN        0.0  NaN    0.0     6970.0  2023-08-18
# 429     0.0        NaN        0.0  NaN    0.0        NaN  2023-08-14
# 430     NaN        NaN        0.0  NaN    0.0        NaN  2023-08-11
# 434     0.0        NaN        0.0  NaN    0.0    10925.0  2023-07-24
# 435     0.0        NaN        0.0  NaN    0.0     5960.0  2023-07-24
# 436     0.0        NaN        0.0  NaN    0.0    43560.0  2023-07-24
# 437     0.0        NaN        0.0  NaN    0.0    11436.0  2023-07-24
# 438     0.0        NaN        0.0  NaN    0.0    10466.0  2023-07-24
# 439     0.0        NaN        0.0  NaN    0.0     9614.0  2023-07-24
# 442     0.0        NaN        0.0  NaN    0.0     5759.0  2023-07-21
# 443     0.0        NaN        0.0  NaN    0.0     5759.0  2023-07-21
# 444     0.0        NaN        0.0  NaN    0.0     6534.0  2023-07-21
# 445     0.0        NaN        0.0  NaN    0.0    15000.0  2023-07-21
# 457     0.0        NaN        0.0  NaN    0.0     5663.0  2024-01-11
# 468     0.0        NaN        0.0  NaN    0.0   534481.0  2024-01-08
# 475     0.0        NaN        0.0  NaN    0.0    23522.0  2024-01-05
# 480     NaN        NaN        0.0  NaN    0.0     8276.0  2024-01-05
# 488     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-22
# 489     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-21
# 490     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-19
# 491     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-12
# 492     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-12
# 494     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-01
# 501     0.0        NaN        0.0  NaN    0.0        NaN  2023-11-02
# 503     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-27
# 506     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-20
# 507     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-18
# 509     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-16
# 512     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-05
# 513     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-04
# 514     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-04
# 515     0.0        NaN        0.0  NaN    0.0        NaN  2023-10-03
# 519     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-28
# 520     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-27
# 521     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-26
# 522     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-22
# 523     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-19
# 525     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-12
# 526     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-12
# 527     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-12
# 528     0.0        NaN        0.0  NaN    0.0        NaN  2023-09-12
# 545     0.0        NaN        0.0  NaN    0.0    46035.0  2023-12-26
# 568     0.0        NaN        0.0  NaN    0.0        NaN  2023-12-22
# 646     0.0        NaN        0.0  NaN    0.0     4356.0  2024-01-04
# 655     0.0        NaN        0.0  NaN    0.0    11761.0  2024-01-03
# 690     0.0        NaN        0.0  NaN    0.0    69696.0  2024-01-12
# 691     0.0        NaN        0.0  NaN    0.0   221285.0  2024-01-11
# 719     0.0        NaN        0.0  NaN    0.0    15682.0  2024-01-12
# 1104    0.0        NaN        0.0  NaN    0.0   131116.0  2024-01-15
# 1109    0.0        NaN        0.0  NaN    0.0     7087.0  2024-01-12
# 1142    0.0        NaN        0.0  NaN    0.0    64226.0  2024-01-12
# 1418    NaN        NaN        0.0  NaN    0.0        NaN  2024-01-11
# 1467    0.0        NaN        0.0  NaN    0.0   304049.0  2024-01-05
# 1473    NaN        NaN        0.0  NaN    0.0  1350360.0  2024-01-05
# 1474    NaN        NaN        0.0  NaN    0.0  2381425.0  2024-01-04
# 1475    0.0        NaN        0.0  NaN    0.0  6969600.0  2024-01-04
# 1812    0.0        NaN        0.0  NaN    0.0     6843.0  2024-01-10
# 1814    0.0        NaN        0.0  NaN    0.0    28314.0  2024-01-05
# 1931    0.0        NaN        0.0  NaN    0.0  1045440.0  2023-12-22
# 2004    0.0        NaN        0.0  NaN    0.0        NaN  2023-09-08
# 2238    0.0        NaN        0.0  NaN    0.0   986198.0  2024-01-16
# 2248    NaN        NaN        0.0  NaN    0.0     8316.0  2024-01-11
# 2259    0.0        NaN        0.0  NaN    0.0    12005.0  2024-01-05
# 2280    0.0        NaN        0.0  NaN    0.0        NaN  2023-09-01
# 2283    0.0        NaN        0.0  NaN    0.0        NaN  2023-07-27
# 2290    0.0        NaN        0.0  NaN    0.0    86249.0  2023-07-21
# 2334    0.0        NaN        0.0  NaN    0.0      25317  2024-01-05
# 2378    NaN        NaN        0.0  NaN    0.0     9549.0  2023-12-27
# 2520    0.0        NaN        0.0  NaN    0.0    64992.0  2024-01-12
# 2543    NaN        NaN        0.0  NaN    0.0    11252.0  2024-01-08
# 2612    0.0        NaN        0.0  NaN    0.0       5271  2024-01-08
# 3034    0.0        NaN        0.0  NaN    0.0     3916.0  2024-01-10
# 3292    0.0        NaN        0.0  NaN    0.0     9583.0  2023-12-20
# 3510    0.0        NaN        0.0  NaN    0.0      20909  2023-12-29
# 3511    0.0        NaN        0.0  NaN    0.0     124146  2023-12-29
# 3518    0.0        NaN        0.0  NaN    0.0      43560  2023-12-22
# 3531    0.0        NaN        0.0  NaN    0.0       3920  2023-12-18
# 4039    0.0        NaN        0.0  NaN    0.0        NaN  2023-09-08
# 4040    0.0        NaN        0.0  NaN    0.0        NaN  2023-09-05
# 4153    NaN        NaN        0.0  NaN    0.0        NaN  2023-09-27
# 4159    NaN        NaN        0.0  NaN    0.0        NaN  2023-08-31
# 4160    0.0        NaN        0.0  NaN    0.0        NaN  2023-08-28
# 4163    NaN        NaN        0.0  NaN    0.0        NaN  2023-08-23
# 4455    0.0        NaN        0.0  NaN    0.0      61420  2023-12-15
# 5831    0.0        NaN        0.0  NaN    0.0     4291.0  2023-12-11
# 6152    0.0        NaN        0.0  NaN    0.0    87120.0  2024-01-03
# 6800    0.0        NaN        0.0  NaN    0.0     3049.0  2024-01-16
#
#       sold_price     sqft stories           type year_built  is_price_reduced  \
# 41         74000      NaN     NaN           land        NaN             False
# 139       102000      NaN     NaN           land        NaN             False
# 144       147500      NaN     NaN           land        NaN             False
# 246         7700      NaN     NaN           land        NaN             False
# 255        15400      NaN     NaN           land        NaN             False
# 256         6930      NaN     NaN           land        NaN             False
# 258        20900      NaN     NaN           land        NaN             False
# 265         1122      NaN     NaN           land        NaN             False
# 267          385      NaN     NaN           land        NaN             False
# 268          308      NaN     NaN           land        NaN             False
# 269         1122      NaN     NaN           land        NaN             False
# 270          583      NaN     NaN           land        NaN             False
# 271         2585      NaN     NaN           land        NaN             False
# 274        22000      NaN     NaN           land        NaN             False
# 334       370000      NaN     NaN           land        NaN             False
# 378       227000   4512.0     NaN   multi_family     1880.0             False
# 392      1200000  32106.0     NaN   multi_family     1920.0             False
# 403        25000      NaN     NaN           land        NaN             False
# 410   27065000.0      NaN     NaN  single_family        NaN             False
# 422       3800.0      NaN     NaN           land        NaN             False
# 425       4500.0      NaN     NaN           land        NaN             False
# 426       5000.0      NaN     NaN           land        NaN             False
# 429     119900.0      NaN     NaN          condo        NaN             False
# 430     359900.0      NaN     NaN           None        NaN             False
# 434     130000.0      NaN     NaN  single_family        NaN             False
# 435      68000.0      NaN     NaN  single_family        NaN             False
# 436     142000.0      NaN     NaN  single_family        NaN             False
# 437     207000.0      NaN     NaN  single_family        NaN             False
# 438     346001.0      NaN     NaN  single_family        NaN             False
# 439     275000.0      NaN     NaN          other        NaN             False
# 442      10000.0      NaN     NaN  single_family        NaN             False
# 443      10000.0      NaN     NaN  single_family        NaN             False
# 444     230000.0      NaN     NaN  single_family        NaN             False
# 445     475000.0      NaN     NaN  single_family        NaN             False
# 457        76000      NaN     NaN           land        NaN             False
# 468       453990      NaN     NaN           land        NaN             False
# 475       107500      NaN     NaN           land        NaN             False
# 480       325000   4344.0     2.0   multi_family     1930.0             False
# 488       533600      NaN     NaN           land        NaN             False
# 489       666700      NaN     NaN           land        NaN             False
# 490       378000      NaN     NaN           land        NaN             False
# 491       307300      NaN     NaN           land        NaN             False
# 492       200000      NaN     NaN           land        NaN             False
# 494       565000      NaN     NaN           land        NaN             False
# 501       362800      NaN     NaN           land        NaN             False
# 503       366100      NaN     NaN           land        NaN             False
# 506       115000      NaN     NaN           land        NaN             False
# 507       721000      NaN     NaN           land        NaN             False
# 509       512500      NaN     NaN           land        NaN             False
# 512       656700      NaN     NaN          condo        NaN             False
# 513       499300      NaN     NaN  single_family        NaN             False
# 514       718800      NaN     NaN          condo        NaN             False
# 515       120000      NaN     NaN           land        NaN             False
# 519       550000      NaN     NaN          condo        NaN             False
# 520       348900      NaN     NaN           land        NaN             False
# 521       366600      NaN     NaN           land        NaN             False
# 522       824800      NaN     NaN          condo        NaN             False
# 523      1312400      NaN     NaN           land        NaN             False
# 525       371300      NaN     NaN           land        NaN             False
# 526       748900      NaN     NaN          condo        NaN             False
# 527       350300      NaN     NaN           land        NaN             False
# 528      1059800      NaN     NaN          condo        NaN             False
# 545      1900000      NaN     NaN   multi_family     1949.0             False
# 568       485000      NaN     NaN   multi_family     1950.0             False
# 646        99275      NaN     NaN           land        NaN             False
# 655       120000      NaN     NaN           land        NaN             False
# 690        60000      NaN     NaN           land        NaN             False
# 691        55000      NaN     NaN           land        NaN             False
# 719        28000      NaN     NaN           land        NaN             False
# 1104      155000      NaN     NaN           land        NaN             False
# 1109      159000      NaN     NaN           land        NaN             False
# 1142      224825      NaN     NaN           land        NaN             False
# 1418      690000      NaN     NaN  single_family     1961.0             False
# 1467     2016000      NaN     NaN           land        NaN             False
# 1473      310000      NaN     NaN           land        NaN             False
# 1474      820000      NaN     NaN           land        NaN             False
# 1475     2016000      NaN     NaN           land        NaN              True
# 1812      410000      NaN     NaN           land        NaN             False
# 1814      330000      NaN     NaN           land        NaN             False
# 1931      370512      NaN     NaN           land        NaN             False
# 2004      494800      NaN     NaN           land        NaN             False
# 2238      243000      NaN     NaN           land        NaN             False
# 2248      550000   2304.0     NaN   multi_family     1962.0             False
# 2259       25000      NaN     NaN           land        NaN             False
# 2280      710000      NaN     NaN  single_family        NaN             False
# 2283      534900      NaN     NaN          condo        NaN             False
# 2290      170000      NaN     1.0         mobile        NaN             False
# 2334       64000      NaN     NaN           land        NaN             False
# 2378      425000   1920.0     NaN   multi_family     1980.0             False
# 2520      270000      NaN     NaN           land        NaN             False
# 2543      410000      NaN     1.0   multi_family     1920.0             False
# 2612       30000      NaN     NaN           land        NaN             False
# 3034      120000      NaN     NaN           land        NaN             False
# 3292      750000      NaN     NaN           land        NaN             False
# 3510      822500      NaN     NaN           land        NaN             False
# 3511      325000      NaN     NaN           land        NaN             False
# 3518      157000      NaN     NaN           land        NaN             False
# 3531       50000      NaN     NaN           land        NaN             False
# 4039      792600      NaN     NaN          condo        NaN             False
# 4040      358900      NaN     NaN           land        NaN             False
# 4153      162000      NaN     NaN           None        NaN             False
# 4159      294988      NaN     NaN           None        NaN             False
# 4160      676860      NaN     NaN          other        NaN             False
# 4163      349990      NaN     NaN           None        NaN             False
# 4455      350000      NaN     NaN           land        NaN             False
# 5831       90000      NaN     NaN           land        NaN             False
# 6152      105000      NaN     NaN           land        NaN             False
# 6800      128500      NaN     NaN           land        NaN             False
#
#                         list_date list_price  listing_id              city  \
# 41    2021-10-06T16:40:40.000000Z      90000  2935179051           Lincoln
# 139   2023-10-09T22:26:57.000000Z     110000  2960391412           Spencer
# 144   2023-12-12T17:26:25.000000Z     160000  2962409797            Edmond
# 246   2023-09-14T18:27:45.000000Z      12999  2959674302        Charleston
# 255          2023-06-08T21:27:07Z      20000  2956543845        Charleston
# 256          2023-08-04T19:17:44Z      19999  2958387594        Charleston
# 258          2023-07-18T17:41:05Z      35000  2957803138        Charleston
# 265          2023-05-31T16:25:31Z       5000  2956242830        Charleston
# 267          2023-05-31T16:25:31Z       5000  2956242804        Charleston
# 268          2023-05-31T16:25:31Z       5000  2956242828        Charleston
# 269          2023-05-31T16:25:31Z       5000  2956242817        Charleston
# 270          2023-05-31T16:25:31Z       5000  2956242813        Charleston
# 271          2023-05-31T18:27:13Z       5000  2956250016        Charleston
# 274          2023-05-08T15:27:38Z      25000  2955380751        Charleston
# 334   2022-09-02T18:18:05.000000Z     395000  2947407483        Montgomery
# 378   2023-08-29T17:33:03.000000Z     275000  2959182819          Hartford
# 392   2023-03-27T14:26:49.000000Z    2350000  2953936748          Hartford
# 403   2023-10-03T02:37:39.000000Z      45000  2960191491          Hartford
# 410                          None        NaN        None       Springfield
# 422          2023-05-01T00:07:57Z     4000.0  2955116778       Springfield
# 425          2023-05-26T14:05:36Z     7500.0  2956129203       Springfield
# 426          2023-05-26T15:46:36Z     6500.0  2956135116       Springfield
# 429                          None        NaN        None       Springfield
# 430                          None        NaN        None       Springfield
# 434                          None        NaN        None       Springfield
# 435                          None        NaN        None       Springfield
# 436                          None        NaN        None       Springfield
# 437                          None        NaN        None       Springfield
# 438                          None        NaN        None       Springfield
# 439                          None        NaN        None       Springfield
# 442                          None        NaN        None       Springfield
# 443                          None        NaN        None       Springfield
# 444                          None        NaN        None       Springfield
# 445                          None        NaN        None       Springfield
# 457   2023-07-27T19:18:01.000000Z      76000  2958104378       Little Rock
# 468   2023-07-01T13:50:14.000000Z     490800  2957307707       Little Rock
# 475   2023-09-08T17:46:32.000000Z     124900  2959499539       Little Rock
# 480   2023-11-04T21:17:00.000000Z     325000  2961369623       Little Rock
# 488                          None        NaN        None          Columbus
# 489                          None        NaN        None          Columbus
# 490                          None        NaN        None  Canal Winchester
# 491                          None        NaN        None  Canal Winchester
# 492                          None        NaN        None            Dublin
# 494                          None        NaN        None          Columbus
# 501                          None        NaN        None  Canal Winchester
# 503                          None        NaN        None          Columbus
# 506                          None        NaN        None          Columbus
# 507                          None        NaN        None          Columbus
# 509                          None        NaN        None          Columbus
# 512                          None        NaN        None          Columbus
# 513                          None        NaN        None       Westerville
# 514                          None        NaN        None          Columbus
# 515                          None        NaN        None          Columbus
# 519                          None        NaN        None          Columbus
# 520                          None        NaN        None  Canal Winchester
# 521                          None        NaN        None  Canal Winchester
# 522                          None        NaN        None          Columbus
# 523                          None        NaN        None       Westerville
# 525                          None        NaN        None  Canal Winchester
# 526                          None        NaN        None          Columbus
# 527                          None        NaN        None  Canal Winchester
# 528                          None        NaN        None          Columbus
# 545   2023-09-04T13:24:48.000000Z    2200000  2959337342           Phoenix
# 568   2023-06-28T01:07:26.000000Z     495000  2957128899           Phoenix
# 646   2023-12-02T21:29:33.000000Z      99275  2962191323             Salem
# 655   2023-11-08T18:45:51.000000Z     120000  2961460062             Salem
# 690   2023-11-15T16:21:28.000000Z      72000  2961695897       Tallahassee
# 691   2024-01-11T14:20:54.000000Z      58000  2963107454       Tallahassee
# 719   2023-11-15T01:07:19.000000Z      25000  2961680170        Harrisburg
# 1104  2023-10-25T13:48:26.000000Z     185000  2960852980           Henrico
# 1109  2023-12-13T11:57:36.000000Z     114500  2962510291           Henrico
# 1142  2023-01-20T05:14:03.000000Z     275000  2951620154         Annapolis
# 1418  2022-10-08T03:24:32.000000Z     900000  2948706621           Raleigh
# 1467  2023-09-29T15:39:05.000000Z          1  2960107502             Boone
# 1473  2023-07-27T13:31:43.000000Z     310000  2958088524             Boone
# 1474  2023-09-27T17:10:58.000000Z     820000  2960034012             Boone
# 1475  2024-01-05T21:26:29.000000Z          1  2962974651             Boone
# 1812  2022-02-01T05:25:28.000000Z     385000  2939664555           Phoenix
# 1814  2017-11-20T03:24:16.000000Z     375000   605232740           Phoenix
# 1931  2023-04-05T18:26:26.000000Z     366000  2954254571           Garnett
# 2004                         None        NaN        None       Westerville
# 2238  2023-10-04T00:26:14.000000Z     249900  2960222908           Olympia
# 2248  2023-06-23T18:24:26.000000Z     575000  2957022448           Olympia
# 2259  2023-12-21T20:26:05.000000Z      25000  2962691451           Olympia
# 2280                         None        NaN        None         Nashville
# 2283                         None        NaN        None         Nashville
# 2290                         None        NaN        None           Joelton
# 2334  2021-09-30T21:25:40.000000Z      81000  2934973079           Lincoln
# 2378  2023-11-10T21:20:16.000000Z     425000  2961539260           Olympia
# 2520  2023-08-01T18:31:04.000000Z     299000  2958250974           Atlanta
# 2543  2023-12-04T15:17:21.000000Z     425000  2962208171           Atlanta
# 2612  2023-10-12T19:55:01.000000Z      35000  2960497461        Saint Paul
# 3034  2023-11-15T17:10:24.000000Z     135000  2961698082        Providence
# 3292  2023-10-12T23:02:45.000000Z     750000  2960506001            Denver
# 3510  2022-05-01T17:09:40.000000Z     950000  2942628229       Carson City
# 3511  2023-05-01T18:03:21.000000Z     329000  2955134878       Carson City
# 3518  2023-01-02T03:33:54.000000Z     189000  2951028850       Carson City
# 3531  2023-11-25T21:10:26.000000Z      75000  2961961814       Carson City
# 4039                         None        NaN        None          Columbus
# 4040                         None        NaN        None  Canal Winchester
# 4153                         None        NaN        None      Indianapolis
# 4159                         None        NaN        None      Indianapolis
# 4160                         None        NaN        None      Indianapolis
# 4163                         None        NaN        None      Indianapolis
# 4455  2023-06-16T17:28:18.000000Z     368900  2956804020       Carson City
# 5831  2023-09-08T19:14:12.000000Z      99000  2959504006           Trenton
# 6152  2023-11-30T08:29:08.000000Z      99000  2962069754       Little Rock
# 6800  2023-11-08T21:34:23.000000Z     125000  2961467386        Providence
#
#             lat         lon                                 line postal_code  \
# 41    40.711364  -96.617101                      7646 Isidore Dr       68516
# 139   35.540562  -97.351857                       6700 N Post Rd       73084
# 144   35.595714  -97.411402                    12317 Thelmas Way       73013
# 246   38.418295  -81.584571                    2310 Mile Fork Rd       25312
# 255         NaN         NaN                     Youngs Hollow Rd       25320
# 256   38.294911  -81.628972                    1441 Cane Fork Rd       25314
# 258    38.48811  -81.596275                    5575 Legg Fork Rd       25320
# 265   38.332075  -81.497943              1077 Campbells Creek Dr       25306
# 267         NaN         NaN                      Maple Hollow Rd       25311
# 268   38.306225  -81.571146                     5744 Victory Ave       25304
# 269   38.331983  -81.498337               155 Campbells Creek Dr       25306
# 270         NaN         NaN                    39 Meadowbrook Dr       25311
# 271         NaN         NaN                      4505 Woodrum Ln       25313
# 274   38.318442  -81.569243                  5407 Kanawha Ave SE       25304
# 334   32.155112  -86.220291             3180 E Old Hayneville Rd       36105
# 378   41.760903  -72.689597                       103 Babcock St       06106
# 392   41.766034  -72.709751                   527 Farmington Ave       06105
# 403   41.733843  -72.711459                       40 Brinley Ave       06106
# 410         NaN         NaN             3501 Old Jacksonville Rd       62711
# 422   39.771624  -89.627975                         19 Garnet Ct       62703
# 425   39.781624  -89.646568                        1900 S 7th St       62703
# 426   39.789941  -89.656533                     1035 S Spring St       62704
# 429   39.820301  -89.704559                        83 Amherst Dr       62702
# 430         NaN         NaN                      4615 Lasalle Ct       62711
# 434   39.760722  -89.703887                        416 Yeoman Dr       62704
# 435   39.775775  -89.637265                       2237 S 14th St       62703
# 436   39.775651  -89.582633                3532 E State Route 29       62712
# 437   39.792227  -89.691555                      933 Westview Dr       62704
# 438   39.774194  -89.724453                    2108 Dubsdread Dr       62711
# 439    39.78819  -89.651613                        1201 S 4th St       62703
# 442   39.814596   -89.66286                    565 W Elliott Ave       62702
# 443   39.814594  -89.663002                    565 W Elliott Ave       62702
# 444   39.761837  -89.728436                      3913 Marryat Dr       62711
# 445   39.703407  -89.702628                  2804 Castlerock Rdg       62711
# 457         NaN         NaN                202 Fletcher Ridge Dr       72223
# 468         NaN         NaN                       00012 Denny Rd       72223
# 475   34.772842  -92.481706                       120 Sezanne Ct       72223
# 480   34.725859   -92.29413                    2405 S Battery St       72206
# 488   40.113177  -82.862281                  6515 Bowery Peak Ln       43081
# 489   40.113637  -82.861616                  6540 Bowery Peak Ln       43081
# 490   39.890589  -82.850765                   5409 Coble Park Dr       43110
# 491   39.891861  -82.852431               5342 Shannon Square Dr       43110
# 492   40.079033  -83.106535                   6081 Deer Bluff Pl       43017
# 494   40.113801  -82.861603                  6548 Bowery Peak Ln       43081
# 501   39.890629  -82.851531                   5379 Coble Park Dr       43110
# 503   39.911445  -82.834975                    6007 Bears Run Rd       43232
# 506   40.097692  -82.872195                    5416 Seclusion Dr       43081
# 507   40.096385  -82.870161                   5498 Cove Haven St       43081
# 509   40.116416  -82.862656                       5715 Vance Way       43081
# 512         NaN         NaN                   2897 Katmai Dr # A       43228
# 513   40.096367  -82.866679                      5626 Godetia St       43081
# 514         NaN         NaN                    2852 Kobuk Dr # A       43228
# 515   40.097629   -82.87072                    5460 Seclusion Dr       43081
# 519         NaN         NaN                       1204 Hamlet St       43201
# 520   39.890613  -82.851225                   5391 Coble Park Dr       43110
# 521   39.890605  -82.851072                   5397 Coble Park Dr       43110
# 522         NaN         NaN                    2880 Kobuk Dr # A       43228
# 523   40.112546  -82.863474                6495 Cold Mountain Dr       43081
# 525   39.891837  -82.851983               5360 Shannon Square Dr       43110
# 526         NaN         NaN                    2876 Kobuk Dr # A       43228
# 527   39.890645  -82.851837                   5367 Coble Park Dr       43110
# 528         NaN         NaN                    2844 Kobuk Dr # A       43228
# 545   33.459104 -112.031727                  2316 E Roosevelt St       85006
# 568   33.397853 -112.089102                      5237 S 14th Ave       85041
# 646   44.959267 -123.024055                    2100 Hazel Ave NE       97301
# 655   44.966904 -123.034397               2700 Block Front St NE       97301
# 690   30.629042  -84.286999                  619 Earls Slough Ct       32312
# 691   30.292709   -84.15275                  11408 Regiment Loop       32305
# 719   40.354017  -76.758368                    Walnut Ave Lot 11       17112
# 1104  37.456369  -77.246928                 5693 Charles City Rd       23231
# 1109  37.599113  -77.471974                   2307 Wedgewood Ave       23228
# 1142  38.991707  -76.589478                   1907 Mackiebeth Ct       21401
# 1418  35.779021  -78.688667                       3811 Marcom St       27606
# 1467        NaN         NaN                             140th St       50036
# 1473        NaN         NaN                             Peony Ln       50036
# 1474        NaN         NaN                          Division St       50036
# 1475        NaN         NaN                             140th St       50036
# 1812  33.481536 -112.042435                       2938 N 18th Pl       85016
# 1814  33.315008 -112.074197                14612 S 1st St Lot 32       85048
# 1931        NaN         NaN                          Highway 321       29201
# 2004  40.112931   -82.86223                    5744 Pocatello Dr       43081
# 2238        NaN         NaN  9207 Tract B Old Olympic Highway NW       98502
# 2248  47.019055 -122.886233         3208 Hawthorne Pl SE Unit 10       98501
# 2259        NaN         NaN                     Littlerock Rd SW       98512
# 2280        NaN         NaN                     2122B 12th Ave N       37208
# 2283  36.146606  -86.816841               303 31st Ave N Apt 206       37203
# 2290  36.288843  -86.918623              6000 Marrowbone Lake Rd       37080
# 2334  40.710544  -96.616681                   7720 Augustine Ave       68516
# 2378  47.064723 -122.743852            1433 Lapush Way NE Unit A       98516
# 2520        NaN         NaN           1886 Shalimar Dr NE Lot 14       30345
# 2543  33.725041  -84.409732                   675 Mayland Ave SW       30310
# 2612  44.956887  -93.060556                         941 3rd St E       55106
# 3034  41.829426  -71.459788                        61 Leander St       02909
# 3292  39.742909 -105.045502                        1641 Utica St       80204
# 3510  39.098858 -119.855927                3601 Meeks Ct Lot 158       89705
# 3511  39.188387 -119.812979                   4280 Timberline Dr       89703
# 3518  39.156592 -119.778049                1135 Crain Cir Lot 42       89703
# 3531  39.162104  -119.75962                          S Pratt Ave       89701
# 4039        NaN         NaN                   2909 Katmai Dr # A       43228
# 4040  39.890677  -82.852449                   5343 Coble Park Dr       43110
# 4153        NaN         NaN                 4030 N Edmondson Ave       46226
# 4159        NaN         NaN               4736 Topaz Pointe Blvd       46235
# 4160        NaN         NaN                   7428 Glen Park Way       46259
# 4163        NaN         NaN                    10715 Mangrove Dr       46239
# 4455   39.19989 -119.820353                  4670 Wagon Wheel Rd       89703
# 5831  40.225716  -74.783066                    474 Riverside Ave       08618
# 6152  34.573022  -92.306594                      1827 Lorance Dr       72206
# 6800  41.833165   -71.43976                     32 Grosvenor Ave       02908
#
#                state state_code price_reduced_amount property_id  basement  \
# 41          Nebraska         NE                  0.0  9078473372         0
# 139         Oklahoma         OK                  0.0  7480938180         0
# 144         Oklahoma         OK                  0.0  9031371252         0
# 246    West Virginia         WV                  0.0  9812715777         0
# 255    West Virginia         WV                  0.0  9895387158         0
# 256    West Virginia         WV                  0.0  3975252838         0
# 258    West Virginia         WV                  0.0  9727111037         0
# 265    West Virginia         WV                  0.0  3263346436         0
# 267    West Virginia         WV                  0.0  9500733492         0
# 268    West Virginia         WV                  0.0  3233095968         0
# 269    West Virginia         WV                  0.0  3632053777         0
# 270    West Virginia         WV                  0.0  9021324566         0
# 271    West Virginia         WV                  0.0  9577608280         0
# 274    West Virginia         WV                  0.0  3853468411         0
# 334          Alabama         AL                  0.0  9371305836         0
# 378      Connecticut         CT              20000.0  4104926733         1
# 392      Connecticut         CT                  0.0  4750734663         1
# 403      Connecticut         CT                  0.0  3111256269         0
# 410         Illinois         IL                  0.0  9627477899         0
# 422         Illinois         IL                800.0  8142643320         0
# 425         Illinois         IL               3500.0  9796933427         0
# 426         Illinois         IL                  0.0  8217312865         0
# 429         Illinois         IL                  0.0  8559138865         0
# 430         Illinois         IL                  0.0  9526532270         0
# 434         Illinois         IL                  0.0  7566735445         0
# 435         Illinois         IL                  0.0  8487172216         0
# 436         Illinois         IL                  0.0  8629721141         0
# 437         Illinois         IL                  0.0  8907724492         0
# 438         Illinois         IL                  0.0  7311351941         0
# 439         Illinois         IL                  0.0  9515169963         0
# 442         Illinois         IL                  0.0  7222439436         0
# 443         Illinois         IL                  0.0  8739121995         0
# 444         Illinois         IL                  0.0  7237341779         0
# 445         Illinois         IL                  0.0  8268080483         0
# 457         Arkansas         AR                  0.0  9934955122         0
# 468         Arkansas         AR                  0.0  9118590787         0
# 475         Arkansas         AR                  0.0  7567034580         0
# 480         Arkansas         AR              40000.0  7526785866         0
# 488             Ohio         OH                  0.0  9951478357         0
# 489             Ohio         OH                  0.0  9282951966         0
# 490             Ohio         OH                  0.0  9172783908         0
# 491             Ohio         OH                  0.0  9008748993         0
# 492             Ohio         OH                  0.0  9815099741         0
# 494             Ohio         OH                  0.0  9947234926         0
# 501             Ohio         OH                  0.0  9316612583         0
# 503             Ohio         OH                  0.0  9418191699         0
# 506             Ohio         OH                  0.0  9811005142         0
# 507             Ohio         OH                  0.0  9878655360         0
# 509             Ohio         OH                  0.0  9217327598         0
# 512             Ohio         OH                  0.0  9632427826         0
# 513             Ohio         OH                  0.0  9414271198         0
# 514             Ohio         OH                  0.0  9280609914         0
# 515             Ohio         OH                  0.0  9868581860         0
# 519             Ohio         OH                  0.0  9177544469         0
# 520             Ohio         OH                  0.0  9689708582         0
# 521             Ohio         OH                  0.0  9716883447         0
# 522             Ohio         OH                  0.0  9303853384         0
# 523             Ohio         OH                  0.0  9691166009         0
# 525             Ohio         OH                  0.0  9440402986         0
# 526             Ohio         OH                  0.0  9531561471         0
# 527             Ohio         OH                  0.0  9757638699         0
# 528             Ohio         OH                  0.0  9945242835         0
# 545          Arizona         AZ              40000.0  1301214169         0
# 568          Arizona         AZ              64000.0  2073480300         0
# 646           Oregon         OR                  0.0  9797790787         0
# 655           Oregon         OR                  0.0  2944061661         0
# 690          Florida         FL               8000.0  5754537698         0
# 691          Florida         FL                  0.0  6179294911         0
# 719     Pennsylvania         PA                  0.0  3092875659         0
# 1104        Virginia         VA                  0.0  5519424144         0
# 1109        Virginia         VA                  0.0  5087432173         0
# 1142        Maryland         MD                  0.0  9753649228         0
# 1418  North Carolina         NC             100000.0  5369653239         0
# 1467            Iowa         IA                  0.0  9960673320         0
# 1473            Iowa         IA               9990.0  9283407773         0
# 1474            Iowa         IA                  0.0  9724131788         0
# 1475            Iowa         IA            2015999.0  9835758220         0
# 1812         Arizona         AZ                  0.0  2499060512         0
# 1814         Arizona         AZ              50000.0  2297880396         0
# 1931  South Carolina         SC                  0.0  9285399098         0
# 2004            Ohio         OH                  0.0  9038126962         0
# 2238      Washington         WA                  0.0  9843064402         0
# 2248      Washington         WA              20000.0  1465929999         0
# 2259      Washington         WA                  0.0  9983851894         0
# 2280       Tennessee         TN                  0.0  9241050124         0
# 2283       Tennessee         TN                  0.0  9036979390         0
# 2290       Tennessee         TN                  0.0  7350121055         0
# 2334        Nebraska         NE                  0.0  9441754045         0
# 2378      Washington         WA                  0.0  1479494802         0
# 2520         Georgia         GA                  0.0  9904165467         0
# 2543         Georgia         GA                  0.0  6349581711         0
# 2612       Minnesota         MN               5000.0  7722271201         0
# 3034    Rhode Island         RI                  0.0  3145269803         0
# 3292        Colorado         CO              50000.0  1987307867         1
# 3510          Nevada         NV                  0.0  9522053165         0
# 3511          Nevada         NV                  0.0  1981463901         1
# 3518          Nevada         NV                  0.0  1699966937         0
# 3531          Nevada         NV                  0.0  1653411809         0
# 4039            Ohio         OH                  0.0  9637850403         0
# 4040            Ohio         OH                  0.0  9101457585         0
# 4153         Indiana         IN                  0.0  9350399869         0
# 4159         Indiana         IN                  0.0  9333826731         0
# 4160         Indiana         IN                  0.0  9654204496         0
# 4163         Indiana         IN                  0.0  9013856578         0
# 4455          Nevada         NV              10100.0  1172603470         0
# 5831      New Jersey         NJ                  0.0  9002148455         0
# 6152        Arkansas         AR                  0.0  8499929092         0
# 6800    Rhode Island         RI                  0.0  3003028850         0
#
#       big_lot  big_yard  carport  central_air  central_heat  city_view  \
# 41          0         0        0            0             0          1
# 139         1         0        0            0             0          0
# 144         1         0        0            0             0          0
# 246         1         0        0            0             0          0
# 255         1         0        0            0             0          0
# 256         1         0        0            0             0          0
# 258         0         0        0            0             0          0
# 265         1         0        0            0             0          0
# 267         1         0        0            0             0          0
# 268         1         0        0            0             0          0
# 269         1         0        0            0             0          0
# 270         1         0        0            0             0          0
# 271         1         0        0            0             0          0
# 274         1         0        0            0             0          0
# 334         1         0        0            0             0          0
# 378         0         0        0            0             0          0
# 392         0         0        0            0             0          0
# 403         0         0        0            0             0          0
# 410         0         0        0            0             0          0
# 422         0         0        0            0             0          0
# 425         0         0        0            0             0          0
# 426         0         0        0            0             0          0
# 429         0         0        0            0             0          0
# 430         0         0        0            0             0          0
# 434         0         0        0            0             0          0
# 435         0         0        0            0             0          0
# 436         0         0        0            0             0          0
# 437         0         0        0            0             0          0
# 438         0         0        0            0             0          0
# 439         0         0        0            0             0          0
# 442         0         0        0            0             0          0
# 443         0         0        0            0             0          0
# 444         0         0        0            0             0          0
# 445         0         0        0            0             0          0
# 457         0         0        0            0             0          0
# 468         0         0        0            0             0          1
# 475         1         0        0            0             0          0
# 480         0         0        0            0             0          0
# 488         0         0        0            0             0          0
# 489         0         0        0            0             0          0
# 490         0         0        0            0             0          0
# 491         0         0        0            0             0          0
# 492         0         0        0            0             0          0
# 494         0         0        0            0             0          0
# 501         0         0        0            0             0          0
# 503         0         0        0            0             0          0
# 506         0         0        0            0             0          0
# 507         0         0        0            0             0          0
# 509         0         0        0            0             0          0
# 512         0         0        0            0             0          0
# 513         0         0        0            0             0          0
# 514         0         0        0            0             0          0
# 515         0         0        0            0             0          0
# 519         0         0        0            0             0          0
# 520         0         0        0            0             0          0
# 521         0         0        0            0             0          0
# 522         0         0        0            0             0          0
# 523         0         0        0            0             0          0
# 525         0         0        0            0             0          0
# 526         0         0        0            0             0          0
# 527         0         0        0            0             0          0
# 528         0         0        0            0             0          0
# 545         1         0        0            0             0          0
# 568         0         0        0            0             0          0
# 646         0         0        0            0             0          0
# 655         0         0        0            0             0          0
# 690         0         0        0            0             0          0
# 691         0         0        0            0             0          0
# 719         0         0        0            0             0          0
# 1104        1         0        0            0             0          0
# 1109        0         0        0            0             0          0
# 1142        0         0        0            0             0          0
# 1418        1         0        0            0             0          1
# 1467        1         0        0            0             0          0
# ...
# 2238                0     0      0                      0                1
# 2248                0     0      0                      0                0
# 2259                0     0      0                      0                0
# 2280                0     0      0                      0                0
# 2283                0     0      0                      0                0
# 2290                0     0      0                      0                0
# 2334                0     0      0                      0                0
# 2378                0     1      0                      1                1
# 2520                0     0      0                      0                0
# 2543                0     0      0                      1                1
# 2612                0     0      0                      0                0
# 3034                0     0      0                      0                0
# 3292                0     0      0                      1                1
# 3510                0     0      0                      0                0
# 3511                0     0      0                      0                0
# 3518                0     0      0                      0                0
# 3531                0     0      0                      0                0
# 4039                0     0      0                      0                0
# 4040                0     0      0                      0                0
# 4153                0     0      0                      0                0
# 4159                0     0      0                      0                0
# 4160                0     0      0                      0                0
# 4163                0     0      0                      0                0
# 4455                0     0      0                      0                0
# 5831                0     0      0                      0                0
# 6152                0     0      0                      0                0
# 6800                0     0      0                      0                0
#
#       shopping  single_story  swimming_pool  trails  two_or_more_stories  \
# 41           0             0              0       0                    0
# 139          0             0              0       0                    0
# 144          0             0              0       0                    0
# 246          0             0              0       0                    0
# 255          0             0              0       0                    0
# 256          0             0              0       0                    0
# 258          0             0              0       0                    0
# 265          0             0              0       0                    0
# 267          0             0              0       0                    0
# 268          0             0              0       0                    0
# 269          0             0              0       0                    0
# 270          0             0              0       0                    0
# 271          0             0              0       0                    0
# 274          0             0              0       0                    0
# 334          0             0              0       0                    0
# 378          0             0              0       0                    0
# 392          0             0              0       0                    0
# 403          1             0              0       0                    0
# 410          0             0              0       0                    0
# 422          0             0              0       0                    1
# 425          0             1              0       0                    0
# 426          0             0              0       0                    0
# 429          0             0              0       0                    0
# 430          0             0              0       0                    0
# 434          0             0              0       0                    0
# 435          0             0              0       0                    0
# 436          0             0              0       0                    0
# 437          0             0              0       0                    0
# 438          0             0              0       0                    0
# 439          0             0              0       0                    0
# 442          0             0              0       0                    0
# 443          0             0              0       0                    0
# 444          0             0              0       0                    0
# 445          0             0              0       0                    0
# 457          0             0              0       0                    0
# 468          0             0              0       0                    0
# 475          0             0              1       0                    0
# 480          0             0              0       0                    1
# 488          0             0              0       0                    0
# 489          0             0              0       0                    0
# 490          0             0              0       0                    0
# 491          0             0              0       0                    0
# 492          0             0              0       0                    0
# 494          0             0              0       0                    0
# 501          0             0              0       0                    0
# 503          0             0              0       0                    0
# 506          0             0              0       0                    0
# 507          0             0              0       0                    0
# 509          0             0              0       0                    0
# 512          0             0              0       0                    0
# 513          0             0              0       0                    0
# 514          0             0              0       0                    0
# 515          0             0              0       0                    0
# 519          0             0              0       0                    0
# 520          0             0              0       0                    0
# 521          0             0              0       0                    0
# 522          0             0              0       0                    0
# 523          0             0              0       0                    0
# 525          0             0              0       0                    0
# 526          0             0              0       0                    0
# 527          0             0              0       0                    0
# 528          0             0              0       0                    0
# 545          0             0              0       0                    0
# 568          0             0              0       0                    0
# 646          1             0              0       0                    0
# 655          1             0              0       0                    0
# 690          0             0              0       0                    0
# 691          0             0              0       0                    0
# 719          0             0              0       0                    0
# 1104         0             0              0       0                    0
# 1109         0             1              0       0                    0
# 1142         0             0              0       0                    0
# 1418         1             0              0       0                    0
# 1467         0             0              0       0                    0
# 1473         0             0              0       0                    0
# 1474         0             0              0       0                    0
# 1475         0             0              0       0                    0
# 1812         0             0              0       0                    0
# 1814         0             0              0       0                    0
# 1931         0             0              0       0                    0
# 2004         0             0              0       0                    0
# 2238         0             0              0       0                    0
# 2248         1             0              0       0                    0
# 2259         0             0              0       0                    0
# 2280         0             0              0       0                    0
# 2283         0             0              0       0                    0
# 2290         0             0              0       0                    0
# 2334         0             0              0       0                    0
# 2378         1             0              0       0                    0
# 2520         1             0              0       0                    0
# 2543         1             1              0       0                    0
# 2612         1             0              0       0                    1
# 3034         0             0              0       0                    0
# 3292         0             0              0       0                    0
# 3510         0             0              0       1                    0
# 3511         0             0              0       0                    0
# 3518         0             0              0       0                    0
# 3531         0             0              0       0                    0
# 4039         0             0              0       0                    0
# 4040         0             0              0       0                    0
# 4153         0             0              0       0                    0
# 4159         0             0              0       0                    0
# 4160         0             0              0       0                    0
# 4163         0             0              0       0                    0
# 4455         0             0              0       0                    0
# 5831         0             0              0       0                    0
# 6152         0             1              0       0                    0
# 6800         0             0              0       0                    0
#
#       updated_kitchen  view  views  washer_dryer
# 41                  0     1      0             0
# 139                 0     0      0             0
# 144                 0     0      0             0
# 246                 0     0      0             0
# 255                 0     0      0             0
# 256                 0     0      0             0
# 258                 0     0      0             0
# 265                 0     0      0             0
# 267                 0     0      0             0
# 268                 0     0      0             0
# 269                 0     0      0             0
# 270                 0     0      0             0
# 271                 0     0      0             0
# 274                 0     0      0             0
# 334                 0     0      0             0
# 378                 0     0      0             0
# 392                 0     0      0             0
# 403                 0     0      0             0
# 410                 0     0      0             0
# 422                 0     0      0             0
# 425                 0     0      0             0
# 426                 0     0      0             0
# 429                 0     0      0             0
# 430                 0     0      0             0
# 434                 0     0      0             0
# 435                 0     0      0             0
# 436                 0     0      0             0
# 437                 0     0      0             0
# 438                 0     0      0             0
# 439                 0     0      0             0
# 442                 0     0      0             0
# 443                 0     0      0             0
# 444                 0     0      0             0
# 445                 0     0      0             0
# 457                 0     0      0             0
# 468                 0     1      0             0
# 475                 0     0      0             0
# 480                 0     0      0             0
# 488                 0     0      0             0
# 489                 0     0      0             0
# 490                 0     0      0             0
# 491                 0     0      0             0
# 492                 0     0      0             0
# 494                 0     0      0             0
# 501                 0     0      0             0
# 503                 0     0      0             0
# 506                 0     0      0             0
# 507                 0     0      0             0
# 509                 0     0      0             0
# 512                 0     0      0             0
# 513                 0     0      0             0
# 514                 0     0      0             0
# 515                 0     0      0             0
# 519                 0     0      0             0
# 520                 0     0      0             0
# 521                 0     0      0             0
# 522                 0     0      0             0
# 523                 0     0      0             0
# 525                 0     0      0             0
# 526                 0     0      0             0
# 527                 0     0      0             0
# 528                 0     0      0             0
# 545                 0     0      0             0
# 568                 0     0      0             0
# 646                 0     1      0             0
# 655                 0     0      0             0
# 690                 0     1      0             0
# 691                 0     0      0             0
# 719                 0     0      0             0
# 1104                0     0      0             0
# 1109                0     0      0             0
# 1142                0     0      0             0
# 1418                0     1      0             0
# 1467                0     0      0             0
# 1473                0     0      0             0
# 1474                0     0      0             0
# 1475                0     0      0             0
# 1812                0     0      0             0
# 1814                0     1      1             0
# 1931                0     0      0             0
# 2004                0     0      0             0
# 2238                0     1      0             0
# 2248                0     0      0             0
# 2259                0     0      0             0
# 2280                0     0      0             0
# 2283                0     0      0             0
# 2290                0     0      0             0
# 2334                0     1      0             0
# 2378                0     1      0             0
# 2520                0     1      0             0
# 2543                0     0      0             0
# 2612                0     0      0             0
# 3034                0     0      0             0
# 3292                1     1      0             0
# 3510                0     1      1             0
# 3511                0     1      0             0
# 3518                0     1      0             0
# 3531                0     1      0             0
# 4039                0     0      0             0
# 4040                0     0      0             0
# 4153                0     0      0             0
# 4159                0     0      0             0
# 4160                0     0      0             0
# 4163                0     0      0             0
# 4455                0     1      0             0
# 5831                0     0      0             0
# 6152                0     1      0             0
# 6800                0     0      0             0

# %% [markdown]
# **-Time on Market, Month sold, Month listed Columns**

# %%
#We could pull just the month (and/or year) from the 'sold date' (and/or list date) columns to make 'month listed', 'month sold' columns
#We could also create a 'time on market' from the 'sold date' and 'month listed' columns

# %% [markdown]
# **-Drop foreclosure Column?**

# %% [markdown]
# **-Create Mean House Sale Value by City Column**

# %%
#(based on Samson's suggestion)
#Drop location (city, state) columns
#create new column that lists the mean house sale value based on the row's corresponding city

# %% [markdown]
# **-Normalize Data**

# %%
#Normalize, scaler?

# %% [markdown]
# At this point, ensure that you have all sales in a dataframe.
# - Is each cell one value, or do some cells have lists?
# - Maybe the "tags" will help create some features.
# - What are the data types of each column?
# - Some sales may not actually include the sale price.  These rows should be dropped.
# - Some sales don't include the property type.
# - There are a lot of None values.  Should these be dropped or replaced with something?

# %%
# load and concatenate data here
# drop or replace values as necessary

# %% [markdown]
# Consider the fact that with tags, there are a lot of categorical variables.
# - How many columns would we have if we OHE tags, city and state?
# - Perhaps we can get rid of tags that have a low frequency.

# %%
# OHE categorical variables here
# tags will have to be done manually

# %% [markdown]
# - Sales will vary drastically between cities and states.  Is there a way to keep information about which city it is without OHE such as using central tendency?
# - Could we label encode or ordinal encode?  Yes, but this may have undesirable effects, giving nominal data ordinal values.
# - If you replace cities or states with numerical values, make sure that the data is split so that we don't leak data into the training selection. This is a great time to train test split. Compute on the training data, and join these values to the test data
# - Drop columns that aren't needed.
# - Don't keep the list price because it will be too close to the sale price.

# %%
# perform train test split here
# do something with state and city
# drop any other not needed columns

# %% [markdown]
# **STRETCH**
#
# - You're not limited to just using the data provided to you. Think/ do some research about other features that might be useful to predict housing prices.
# - Can you import and join this data? Make sure you do any necessary preprocessing and make sure it is joined correctly.
# - Example suggestion: could mortgage interest rates in the year of the listing affect the price?

# %%
# import, join and preprocess new data here

# %% [markdown]
# Remember all of the EDA that you've been learning about?  Now is a perfect time for it!
# - Look at distributions of numerical variables to see the shape of the data and detect outliers.
# - Scatterplots of a numerical variable and the target go a long way to show correlations.
# - A heatmap will help detect highly correlated features, and we don't want these.
# - Is there any overlap in any of the features? (redundant information, like number of this or that room...)

# %%
# perform EDA here

# %% [markdown]
# Now is a great time to scale the data and save it once it's preprocessed.
# - You can save it in your data folder, but you may want to make a new `processed/` subfolder to keep it organized
